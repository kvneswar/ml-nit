# %% [markdown]
# <a href="https://colab.research.google.com/github/kvneswar/ml-nit/blob/master/03_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd


df = pd.DataFrame({'Audi': [124], 'BMW': [98], 'Mercedes': [113]})

#plt.bar(df.columns, df.values[0])
#plt.title('Sales')
#plt.xlabel('Make')
#plt.ylabel('Frequency/sold')

plt.pie(df.values[0], labels=df.columns, autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7c3cf1da1960>,
# ...
#  [Text(0.4363892652732461, 1.0097348212051898, 'Audi'),
#   Text(-1.0941524656294324, -0.1132712759574722, 'BMW'),
#   Text(0.5380457655904913, -0.9594304321471891, 'Mercedes')],
#  [Text(0.23803050833086148, 0.5507644479301035, '37.0%'),
#   Text(-0.5968104357978722, -0.061784332340439375, '29.3%'),
#   Text(0.2934795085039043, -0.5233256902621032, '33.7%')])
